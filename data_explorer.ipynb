# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %% [markdown]
# # Load data

# %%
df = pd.read_csv('data/01.csv')
df.columns = ['linearity', 'planarity', 'scattering', 'omnivariance', 'anisotropy', 'eigentropy', 'classification', 'intensity']

# %% [markdown]
# # Get statistics per class

# %%
classes = df.classification.unique()

for clas in classes:
    print 'Stats for classification {0}'.format(clas)
    print df[df.classification == clas].describe()
# Out:
# Stats for classification 2.0
#            linearity      planarity     scattering   omnivariance  \
# count  230567.000000  230567.000000  230567.000000  230567.000000
# mean     -516.943653    -154.796971     672.740624       0.169833
# std       486.490266     247.369672     662.017897       0.492772
# min     -6260.099952   -6166.544886       1.352328       0.033768
# 25%      -662.441711    -171.342884     268.350993       0.072207
# 50%      -373.178104     -72.621726     463.846028       0.085590
# 75%      -220.104775     -31.867227     866.878712       0.103397
# max        -0.024805      -0.017298    9193.127503      14.325653
#
#           anisotropy     eigentropy  classification      intensity
# count  230567.000000  230567.000000        230567.0  230567.000000
# mean     -671.740624      -0.054946             2.0     378.708592
# std       662.017897       4.402685             0.0     156.898860
# min     -9192.127503    -162.113883             2.0       2.000000
# ...
